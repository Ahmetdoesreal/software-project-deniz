# %%
# %load_ext autoreload
# %autoreload 2
# %pip install websockets cryptography psutil aiohttp pywin32

from pathlib import Path
import discovery
import runtime_logging
import db_manager
import server_core
from server_core import handle_client, global_timer
# MERT'İN MODÜLÜNÜ İÇERİ AKTARIYORUZ
import db_manager

import asyncio
import websockets
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Requirement already satisfied: websockets in c:\anaconda\lib\site-packages (16.0)
# Requirement already satisfied: cryptography in c:\anaconda\lib\site-packages (43.0.0)
# Requirement already satisfied: psutil in c:\anaconda\lib\site-packages (5.9.0)
# Requirement already satisfied: aiohttp in c:\anaconda\lib\site-packages (3.10.5)
# Requirement already satisfied: pywin32 in c:\anaconda\lib\site-packages (305.1)
# Requirement already satisfied: cffi>=1.12 in c:\anaconda\lib\site-packages (from cryptography) (1.17.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\anaconda\lib\site-packages (from aiohttp) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\anaconda\lib\site-packages (from aiohttp) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\anaconda\lib\site-packages (from aiohttp) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\anaconda\lib\site-packages (from aiohttp) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\anaconda\lib\site-packages (from aiohttp) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\anaconda\lib\site-packages (from aiohttp) (1.11.0)
# Requirement already satisfied: pycparser in c:\anaconda\lib\site-packages (from cffi>=1.12->cryptography) (2.21)
# Requirement already satisfied: idna>=2.0 in c:\anaconda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp) (3.7)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 3) SUNUCUYU BAŞLATMA VE AÇIK TUTMA

# %%
print("🌐 [SUNUCU] Merkezi Sınav Sunucusu Başlatılıyor...")

# 1. Ahmet'in Sistem Hata Kaydedicisini Başlat
# capture_stdout=False ekleyerek Ahmet'in sistemiyle Notebook'un çakışmasını engelliyoruz
runtime_logging.setup_runtime_logging(
    process_name="EXAM_SERVER", 
    log_dir=Path("logs"), 
    capture_stdout=False  # Bunu ekle
)

import os # En üste eklemeyi unutma

async def run_server():
    # --- AYAR: TAM SIFIRLAMA ---
    HARD_RESET = True 

    if HARD_RESET:
        # YENİ EKLENDİ (ENGİN FIX): Windows dosya kilidini kaldırmak için DB bağlantısını kapat!
        # db_manager.py içinde close_db() fonksiyonu yoksa pass geçmemesi için try-except eklendi
        try:
            db_manager.close_db()
        except AttributeError:
            pass # Eğer Mert close_db fonksiyonunu henüz eklemediyse hata vermesin
            
        # 1. Eski SQLite veritabanı dosyasını güvenle sil
        if os.path.exists("exam_monitor.db"):
            try:
                os.remove("exam_monitor.db")
            except Exception as e:
                print(f"⚠️ [UYARI] DB dosyası silinemedi (Muhtemelen hala açık): {e}")
            
        # (Opsiyonel) Log dosyasını da temizle
        if os.path.exists("sinav_raporu_merkezi.jsonl"):
            try:
                os.remove("sinav_raporu_merkezi.jsonl")
            except Exception:
                pass
        
        # 2. RAM'deki listeleri tamamen boşalt
        server_core.active_students.clear()
        server_core.exam_registry.clear()
        
        # 3. Veritabanı tablolarını tertemiz dosyayla sıfırdan yeniden oluştur
        db_manager.init_db() 
        print("💥 [SİSTEM] Fabrika ayarlarına dönüldü. Veritabanı ve RAM SIFIRLANDI!")
    else:
        # ÇÖKME KURTARMA (CRASH RECOVERY) SİSTEMİ
        kurtarilan_durum = db_manager.load_server_state()
        if kurtarilan_durum:
            server_core.active_students = kurtarilan_durum.get("active_students", {})
            server_core.exam_registry = kurtarilan_durum.get("exam_registry", {})
            print(f"🔄 [RECOVERY] Sistem çökmeden kurtarıldı: {len(server_core.active_students)} öğrenci yüklendi.")
        else:
            server_core.active_students.clear()
            server_core.exam_registry.clear()
            print("🧹 [SİSTEM] Yedek bulunamadı, temiz başlanıyor.")

    server_core.dashboard_counter = 0
    
    # 3. Arka plan görevlerini başlat
    asyncio.create_task(global_timer())
    announcer = discovery.ServerAnnouncer(server_host="127.0.0.1", server_port=8765)
    await announcer.start()

    # Sunucuyu başlat
    async with websockets.serve(handle_client, "0.0.0.0", 8765):
        print("🌐 [SUNUCU] Port 8765 dinleniyor. İstemciler bekleniyor...\n")
        try:
            await asyncio.Future()  
        except asyncio.CancelledError:
            print("🛑 [SİSTEM] Sunucu durduruldu.")
        finally:
            await announcer.stop()

# Sistemi Başlat
await run_server()
# Out:
# 🌐 [SUNUCU] Merkezi Sınav Sunucusu Başlatılıyor...
# 💥 [SİSTEM] Fabrika ayarlarına dönüldü. Veritabanı ve RAM SIFIRLANDI!
# [DISCOVERY] Announcing 'default' on UDP port 5354 every 3.0s
# ⏱️ [TIMER] Global timer başladı (generation=1)
# 🌐 [SUNUCU] Port 8765 dinleniyor. İstemciler bekleniyor...
#
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 7688)
# ✅ [EĞİTMEN] Yeni Sınav Aktif Edildi: LAB_1_VIZE
# [EXAM_REGISTERED] {"exam_id": "LAB_1_VIZE"}
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 21707)
# ✅ [EĞİTMEN] Yeni Sınav Aktif Edildi: exam_001
# [EXAM_REGISTERED] {"exam_id": "exam_001"}
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 22111)🎓 [OTURUM] Bahadır Duran (2300007951) CATS üzerinden doğrulandı. BEKLEME ODASINA ALINDI.
# [STUDENT_AUTHENTICATED] {"student_id": "2300007951", "name": "Bahadır Duran"}
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 22437)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 0, "level": "TEMİZ", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 4, "buffered": false, "queued_at": "2026-05-02T12:52:02.651"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST
#    ↳ Skor: %0 (TEMİZ) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 25095)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 0, "level": "TEMİZ", "type": "FOCUS_LOST", "window": "instructor_demo.py - wonderful-feynman-60a098 - Visual Studio Code - Modified", "matched": [], "seq": 5, "buffered": false, "queued_at": "2026-05-02T12:52:07.662"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST
#    ↳ Skor: %0 (TEMİZ) | Pencere: instructor_demo.py - wonderful-feynman-60a098 - Visual Studio Code - Modified
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 27776)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 0, "level": "TEMİZ", "type": "FOCUS_LOST", "window": "instructor_demo.py - wonderful-feynman-60a098 - Visual Studio Code - Modified", "matched": [], "seq": 6, "buffered": false, "queued_at": "2026-05-02T12:52:12.670"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST
#    ↳ Skor: %0 (TEMİZ) | Pencere: instructor_demo.py - wonderful-feynman-60a098 - Visual Studio Code - Modified
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 30386)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 0, "level": "TEMİZ", "type": "FOCUS_LOST", "window": "● server.ipynb - wonderful-feynman-60a098 - Visual Studio Code - Modified", "matched": [], "seq": 7, "buffered": false, "queued_at": "2026-05-02T12:52:17.675"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST
#    ↳ Skor: %0 (TEMİZ) | Pencere: ● server.ipynb - wonderful-feynman-60a098 - Visual Studio Code - Modified
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 32975)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 0, "level": "TEMİZ", "type": "FOCUS_LOST", "window": "● server.ipynb - wonderful-feynman-60a098 - Visual Studio Code - Modified", "matched": [], "seq": 8, "buffered": false, "queued_at": "2026-05-02T12:52:22.683"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST
#    ↳ Skor: %0 (TEMİZ) | Pencere: ● server.ipynb - wonderful-feynman-60a098 - Visual Studio Code - Modified
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 35080)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 9, "buffered": false, "queued_at": "2026-05-02T12:52:27.690"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 36974)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "● server.ipynb - wonderful-feynman-60a098 - Visual Studio Code - Modified", "matched": [], "seq": 10, "buffered": false, "queued_at": "2026-05-02T12:52:32.703"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: ● server.ipynb - wonderful-feynman-60a098 - Visual Studio Code - Modified
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 39095)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 11, "buffered": false, "queued_at": "2026-05-02T12:52:37.711"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 39788)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 12, "buffered": false, "queued_at": "2026-05-02T12:52:42.718"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 40996)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 13, "buffered": false, "queued_at": "2026-05-02T12:52:47.722"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 43017)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 14, "buffered": false, "queued_at": "2026-05-02T12:52:52.732"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 43793)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "Detay: 2300007951", "matched": [], "seq": 15, "buffered": false, "queued_at": "2026-05-02T12:52:57.740"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: Detay: 2300007951
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 45148)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 16, "buffered": false, "queued_at": "2026-05-02T12:53:02.747"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 46671)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 40, "level": "YÜKSEK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 17, "buffered": false, "queued_at": "2026-05-02T12:53:07.753"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %40 (YÜKSEK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 48664)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 18, "buffered": false, "queued_at": "2026-05-02T12:53:12.759"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 50800)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "demo.exe - wonderful-feynman-60a098 - Visual Studio Code", "matched": [], "seq": 19, "buffered": false, "queued_at": "2026-05-02T12:53:17.766"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: demo.exe - wonderful-feynman-60a098 - Visual Studio Code
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 52668)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "dist - Dosya Gezgini", "matched": [], "seq": 20, "buffered": false, "queued_at": "2026-05-02T12:53:22.774"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: dist - Dosya Gezgini
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 54814)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 21, "buffered": false, "queued_at": "2026-05-02T12:53:27.782"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 57125)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 22, "buffered": false, "queued_at": "2026-05-02T12:53:32.796"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 59412)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 23, "buffered": false, "queued_at": "2026-05-02T12:53:37.805"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 59987)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 61792)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 24, "buffered": false, "queued_at": "2026-05-02T12:53:42.813"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 62809)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 64205)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 25, "buffered": false, "queued_at": "2026-05-02T12:53:47.819"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 66366)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 66580)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 26, "buffered": false, "queued_at": "2026-05-02T12:53:52.826"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 66832)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 67448)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 69037)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 27, "buffered": false, "queued_at": "2026-05-02T12:53:57.833"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 71506)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 28, "buffered": false, "queued_at": "2026-05-02T12:54:02.841"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 71986)
# ✅ [EĞİTMEN] Yeni Sınav Aktif Edildi: database
# [EXAM_REGISTERED] {"exam_id": "database"}
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 73075)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 29, "buffered": false, "queued_at": "2026-05-02T12:54:07.846"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 75634)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 30, "buffered": false, "queued_at": "2026-05-02T12:54:12.854"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 76072)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 76879)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 78144)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 31, "buffered": false, "queued_at": "2026-05-02T12:54:17.862"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 80645)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 32, "buffered": false, "queued_at": "2026-05-02T12:54:22.869"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 81712)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 82243)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 83051)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 33, "buffered": false, "queued_at": "2026-05-02T12:54:27.878"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 85014)🚀 [SİSTEM] database sınavı başlatıldı! (0 öğrenci aktif edildi)
# [EXAM_STARTED_ALL] {"exam_id": "database", "count": 0}
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 85593)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 34, "buffered": false, "queued_at": "2026-05-02T12:54:32.886"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 88069)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 35, "buffered": false, "queued_at": "2026-05-02T12:54:37.894"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 88753)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 89456)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 90214)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 90589)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 36, "buffered": false, "queued_at": "2026-05-02T12:54:42.901"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 93121)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 80, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 37, "buffered": false, "queued_at": "2026-05-02T12:54:47.909"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %80 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 95597)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 38, "buffered": false, "queued_at": "2026-05-02T12:54:52.913"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 97951)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 39, "buffered": false, "queued_at": "2026-05-02T12:54:57.923"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 100370)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 40, "buffered": false, "queued_at": "2026-05-02T12:55:02.931"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 102838)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 41, "buffered": false, "queued_at": "2026-05-02T12:55:07.939"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 105292)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 42, "buffered": false, "queued_at": "2026-05-02T12:55:12.945"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 107708)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 43, "buffered": false, "queued_at": "2026-05-02T12:55:17.953"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 110083)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "WhatsApp", "matched": ["whatsapp"], "seq": 44, "buffered": false, "queued_at": "2026-05-02T12:55:22.958"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: WhatsApp
#    ↳ Eşleşen anahtar kelimeler: whatsapp
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 110660)🚨 [GÜVENLİK İHLALİ] 127.0.0.1 IP adresinden 2. bir giriş denemesi reddedildi!
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 112578)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Sınav Sistemi - Öğrenci", "matched": [], "seq": 45, "buffered": false, "queued_at": "2026-05-02T12:55:27.964"}
#
# 🚨 [ALARM] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: İKÜ Sınav Sistemi - Öğrenci
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 113880)[VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "instructor_demo.py - wonderful-feynman-60a098 - Visual Studio Code - Modified", "matched": [], "seq": 1, "buffered": true, "queued_at": "2026-05-02T12:51:47.629"}
#
# 🚨 [ALARM] [GECİKMELİ] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: instructor_demo.py - wonderful-feynman-60a098 - Visual Studio Code - Modified
# [VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "instructor_demo.py - wonderful-feynman-60a098 - Visual Studio Code - Modified", "matched": [], "seq": 2, "buffered": true, "queued_at": "2026-05-02T12:51:52.635"}
#
# 🚨 [ALARM] [GECİKMELİ] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: instructor_demo.py - wonderful-feynman-60a098 - Visual Studio Code - Modified
# [VIOLATION_ALERT] {"student_id": "2300007951", "score": 100, "level": "KRİTİK", "type": "FOCUS_LOST", "window": "İKÜ Eğitici Dashboard", "matched": [], "seq": 3, "buffered": true, "queued_at": "2026-05-02T12:51:57.644"}
#
# 🚨 [ALARM] [GECİKMELİ] 2300007951 → FOCUS_LOST 🧊 DONDURULDU
#    ↳ Skor: %100 (KRİTİK) | Pencere: İKÜ Eğitici Dashboard
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 116326)🎓 [OTURUM] Barış Bağbekleyen (2300005352) CATS üzerinden doğrulandı. BEKLEME ODASINA ALINDI.
# [STUDENT_AUTHENTICATED] {"student_id": "2300005352", "name": "Barış Bağbekleyen"}
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 122727)🚀 [SİSTEM] database sınavı başlatıldı! (1 öğrenci aktif edildi)
# [EXAM_STARTED_ALL] {"exam_id": "database", "count": 1}
# 📊 [SİSTEM] Dashboard güncellendi. (İstek: 126005)[STUDENT_DISCONNECTED] {"student_id": "2300005352"}
#
# 🔌 [KOPTU] Öğrenci 2300005352 hattan düştü. Durumu donduruldu.
# 🛑 [SİSTEM] Sunucu durduruldu.
